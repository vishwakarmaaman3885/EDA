# %% [markdown]
# ## EDA-2(Assignment)
# ## Exploratory Data Analysis  using Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Cabin'].fillna(df['Cabin'].mode()[0],inplace = True)

df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_1501/665544126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# /tmp/ipykernel_1501/665544126.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Q1. Create a countplot to show the number of passengers by gender.

sns.countplot(data=df,x='Sex')

plt.title('Number of Passengers by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')

plt.show()

# %%
# Q2. Create a bar chart to show the number of passengers in each passenger class using different colors.

class_counts = df['Pclass'].value_counts().sort_index()

plt.bar(
    class_counts.index,
    class_counts.values,
    color=['skyblue', 'orange', 'limegreen']
)

plt.title('Number of Passengers by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')

plt.show()

# %%
# Q3. Create a histogram to show the distribution of passenger age.
plt.figure(figsize=(8,5))

plt.hist(df['Age'], bins=20)

plt.title('Distribution of Passenger Age')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')

plt.show()

# %%
# Q4. Create a boxplot to detect outliers in the fare column

plt.figure(figsize=(8,5))
plt.boxplot(df['Fare'])
plt.title('Boxplot of Fare')
plt.ylabel('Fare')

plt.show()

# %%
# Q5. Create a scatterplot to
# a. show the relationship between age and fare.
# b. analyze the relationship between family size (SibSp + Parch) and fare

#a.
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.scatterplot(data=df, x='Age', y='Fare')

plt.title('Relationship Between Age and Fare')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()

# %%
# b.
df['FamilySize'] = df['SibSp'] + df['Parch']

plt.figure(figsize=(8,5))

sns.scatterplot(data=df, x='FamilySize', y='Fare')

plt.title('Relationship Between Family Size and Fare')
plt.xlabel('Family Size (SibSp + Parch)')
plt.ylabel('Fare')

plt.show()

# %%
# Q6. Create a countplot to show survival count by gender.

plt.figure(figsize=(8,5))

sns.countplot(data=df, x='Sex', hue='Survived')

plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')

plt.show()

# Survived = 0 -Did not survive
# Survived = 1 - Survived

# %%
# Q7. Create a bar chart to show survival by passenger class.

plt.figure(figsize=(8,5))

sns.barplot(data=df, x='Pclass', y='Survived')

plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')

plt.show()

# %%
# Q8. Create a heatmap to show correlation between numerical variables

plt.figure(figsize=(10,6))

corr = df.corr(numeric_only=True)

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt='.2f')

plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %%
# Q9. Identify which passenger class paid the highest fare on average.
avg_fare = df.groupby('Pclass')['Fare'].mean()

print(avg_fare)
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
avg_fare = df.groupby('Pclass')['Fare'].mean()

plt.bar(avg_fare.index, avg_fare.values)

plt.title('Average Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Average Fare')

plt.show()

# %%
print(avg_fare.idxmax())
# Out:
# 1

# %%
# Q10. Write at least 5 insights from the dataset based on your visualizations.

# Insight 1: Females had a higher survival rate than males

# The survival count plot showed that a much larger proportion of female passengers survived compared to male passengers. Gender was an important factor in survival.

# Insight 2: First-Class passengers were more likely to survive

# The survival-by-class chart indicated that passengers in First Class had the highest survival rate, while Third-Class passengers had the lowest.

# Insight 3: Most passengers traveled in Third Class

# The passenger class distribution showed that the majority of passengers were in Third Class, making it the largest group on the Titanic.

# Insight 4: Most passengers were young adults

# The age histogram revealed that most passengers were between 20 and 40 years old, with fewer children and elderly passengers.

# Insight 5: Fare distribution contained many outliers

# The fare boxplot showed several extreme values. A small number of passengers paid significantly higher fares than the majority.
